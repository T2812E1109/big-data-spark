# %% [markdown]
# Cada línea del archivo movies.csv representa a un actor que actuó en una película. Si una película tiene diez actores, habrá diez filas para esa película en particular.
#
#
#
# 1. Calcule la cantidad de películas en las que participó cada actor. La salida debe tener dos columnas: actor y conteo. La salida debe ordenarse por el conteo en orden descendente.
#
# 2. Calcule la cantidad de películas producidas cada año. La salida debe tener tres columnas: año, siglo al que pertenece el año y conteo. La salida debe ordenarse por el conteo en orden descendente.
#
# 3. Obtenga la película con la calificación más alta por año. La salida debe tener solo una película por año y debe contener tres columnas: año, título de la película y valoración.

# %%
import findspark

findspark.init()

from pyspark.sql import SparkSession
from pyspark import SparkContext
from pyspark.sql.functions import col, count, desc, udf, rank, countDistinct
from pyspark.sql.types import IntegerType
from pyspark.sql.window import Window

spark = SparkSession.builder.master("local[*]").getOrCreate()

sc: SparkContext = spark.sparkContext

# %%
movies_df = spark.read.csv("./data/s9_in/movies.csv", header=True, inferSchema=True, sep="|")
movie_ratings_df = spark.read.csv("./data/s9_in/movie_ratings.csv", header=True, inferSchema=True, sep="|")

movies_df.printSchema()
movie_ratings_df.printSchema()

movies_df.show(5, truncate=False)
movie_ratings_df.show(5, truncate=False)
# Out:
# root
#  |-- actor: string (nullable = true)
#  |-- pelicula: string (nullable = true)
#  |-- año: integer (nullable = true)
#
# root
#  |-- valoracion: double (nullable = true)
#  |-- pelicula: string (nullable = true)
#  |-- año: integer (nullable = true)
#
# +-----------------+-------------+----+
# |actor            |pelicula     |año |
# +-----------------+-------------+----+
# |McClure, Marc (I)|Freaky Friday|2003|
# |McClure, Marc (I)|Coach Carter |2005|
# |McClure, Marc (I)|Superman II  |1980|
# |McClure, Marc (I)|Apollo 13    |1995|
# |McClure, Marc (I)|Superman     |1978|
# +-----------------+-------------+----+
# only showing top 5 rows
#
# +----------+--------------------------+----+
# |valoracion|pelicula                  |año |
# +----------+--------------------------+----+
# |1.6339    |'Crocodile' Dundee II     |1988|
# |7.6177    |10                        |1979|
# |1.2864    |10 Things I Hate About You|1999|
# |0.3243    |10,000 BC                 |2008|
# |0.3376    |101 Dalmatians            |1996|
# +----------+--------------------------+----+
# only showing top 5 rows

# %%
# 1. Calcule la cantidad de películas en las que participó cada actor. La salida debe tener dos columnas: actor y conteo. La salida debe ordenarse por el conteo en orden descendente.

films_by_actor_df = (
    movies_df
    .groupBy(
        "actor"
    )
    .agg(
        count("pelicula").alias("n_films")
    )
)

films_by_actor_df.orderBy(desc("n_films")).show(
    n=films_by_actor_df.count(),
    truncate=False,
)
# Out:
# +----------------------------+-------+
# |actor                       |n_films|
# +----------------------------+-------+
# |Welker, Frank               |38     |
# |Tatasciore, Fred            |38     |
# |Jackson, Samuel L.          |32     |
# |Harnell, Jess               |31     |
# |Damon, Matt                 |27     |
# |Willis, Bruce               |27     |
# |Cummings, Jim (I)           |26     |
# |Lynn, Sherry (I)            |25     |
# |McGowan, Mickie             |25     |
# |Bergen, Bob (I)             |25     |
# |Hanks, Tom                  |25     |
# |Proctor, Phil               |24     |
# |Pitt, Brad                  |23     |
# |Wilson, Owen (I)            |23     |
# |Cruise, Tom                 |23     |
# |Depp, Johnny                |22     |
# |Morrison, Rana              |22     |
# |Freeman, Morgan (I)         |22     |
# |Williams, Robin (I)         |22     |
# |Buscemi, Steve              |21     |
# |Mann, Danny (I)             |21     |
# |Neeson, Liam                |21     |
# |Murphy, Eddie (I)           |21     |
# |Angel, Jack (I)             |21     |
# |Stiller, Ben                |21     |
# |Diaz, Cameron               |21     |
# |Hoffman, Dustin             |21     |
# |De Niro, Robert             |21     |
# |Simmons, J.K.               |20     |
# |Farmer, Bill (I)            |20     |
# |Roberts, Julia (I)          |20     |
# |Cage, Nicolas               |20     |
# |Travolta, John              |20     |
# |Black, Jack (I)             |20     |
# |Newman, Laraine             |20     |
# |Clooney, George             |20     |
# |Papajohn, Michael           |19     |
# |Rickman, Alan               |19     |
# |Washington, Denzel          |19     |
# |Sandler, Adam (I)           |19     |
# |Downes, Robin Atkin         |19     |
# |Soucie, Kath                |19     |
# |Ratzenberger, John          |18     |
# |Derryberry, Debi            |18     |
# |Ferrell, Will               |18     |
# |Voight, Jon                 |18     |
# |Abernathy, Don              |18     |
# |Rock, Chris (I)             |18     |
# |Schneider, Rob (I)          |18     |
# |Carrey, Jim                 |18     |
# |Bates, Kathy (I)            |17     |
# |Cromwell, James (I)         |17     |
# |Giamatti, Paul              |17     |
# |Baldwin, Alec               |17     |
# |Cleese, John                |17     |
# |Weaving, Hugo               |17     |
# |Darling, Jennifer           |17     |
# |Blum, Steve (IX)            |17     |
# |Rabson, Jan                 |17     |
# |Schwarzenegger, Arnold      |17     |
# |Jenkins, Richard (I)        |17     |
# |LaMarr, Phil                |17     |
# |Ford, Harrison (I)          |17     |
# |Hall, Philip Baker          |17     |
# |Starr, Arne                 |17     |
# |Scott, Seann William        |17     |
# |Rosales Jr., Thomas         |17     |
# |Stallone, Sylvester         |17     |
# |Kidman, Nicole              |17     |
# |Hawn, Phil                  |16     |
# |Macy, William H.            |16     |
# |Banderas, Antonio           |16     |
# |David, Keith (I)            |16     |
# |Lee, Stan (I)               |16     |
# |Sogliuzzo, André            |16     |
# |Gooding Jr., Cuba           |16     |
# |Strong, Tara                |16     |
# |King, Larry (I)             |16     |
# |Gleeson, Brendan (I)        |16     |
# |Coltrane, Robbie            |16     |
# |Wilkinson, Tom (I)          |16     |
# |Howard, Clint               |16     |
# |DeVito, Danny               |16     |
# |Oldman, Gary                |16     |
# |Rogen, Seth                 |16     |
# |Donn, Ray                   |16     |
# |Jolie, Angelina             |16     |
# |Pantoliano, Joe             |16     |
# |Smith, Maggie (I)           |16     |
# |Burton, Corey (I)           |16     |
# |North, Nolan                |15     |
# |Cooper, Chris (I)           |15     |
# |Coolidge, Jennifer          |15     |
# |Favreau, Jon                |15     |
# |Dench, Judi                 |15     |
# |Patrick, Robert (I)         |15     |
# |Nighy, Bill                 |15     |
# |Hinds, Ciarán               |15     |
# |Isaacs, Jason               |15     |
# |McGill, Bruce               |15     |
# |Carell, Steve               |15     |
# |Walken, Christopher         |15     |
# |Bullock, Sandra             |15     |
# |Covert, Allen               |15     |
# |Fiennes, Ralph              |15     |
# |Guzmán, Luis (I)            |15     |
# |Hurt, John                  |15     |
# |Collins, Greg (II)          |15     |
# |Gambon, Michael             |15     |
# |Thorsen, Sven-Ole           |15     |
# |Rush, Geoffrey              |15     |
# |Douglas, Michael (I)        |15     |
# |Wilson, Luke (I)            |15     |
# |Duvall, Robert              |14     |
# |Baker, Dee Bradley          |14     |
# |Reilly, John C. (I)         |14     |
# |Portman, Natalie            |14     |
# |Tobin, John H.              |14     |
# |Zambrana, Maria             |14     |
# |Jones, Tommy Lee            |14     |
# |Spencer, Octavia            |14     |
# |Gugino, Carla               |14     |
# |Cross, David (II)           |14     |
# |Weaver, Sigourney           |14     |
# |Vaughn, Vince               |14     |
# |Paxton, Bill                |14     |
# |Turturro, John              |14     |
# |Tucci, Stanley (I)          |14     |
# |Goodman, John (I)           |14     |
# |Brosnan, Pierce             |14     |
# |Bonham Carter, Helena       |14     |
# |Smith, Will (I)             |14     |
# |Stewart, Patrick (I)        |14     |
# |Jones, James Earl           |14     |
# |Hopkins, Anthony (I)        |14     |
# |Ellis, Chris (I)            |14     |
# |Edgerly, Chris              |14     |
# |Spacey, Kevin               |14     |
# |Glover, Danny               |14     |
# |Higgins, John Michael       |14     |
# |Bumpass, Rodger             |14     |
# |Duncan, Michael Clarke      |14     |
# |Affleck, Ben                |14     |
# |McGee, Jack (I)             |14     |
# |Clark, Blake (I)            |14     |
# |McConaughey, Matthew        |14     |
# |Skarsgård, Stellan          |14     |
# |Plummer, Christopher (I)    |14     |
# |Spall, Timothy              |14     |
# |Scott, Lorna                |14     |
# |Azaria, Hank                |14     |
# |Hill, Jonah                 |14     |
# |Hoffman, Philip Seymour     |14     |
# |Long, Justin (I)            |13     |
# |Margolyes, Miriam           |13     |
# |Tambor, Jeffrey             |13     |
# |Cox, Brian (I)              |13     |
# |Warburton, Patrick          |13     |
# |Stormare, Peter             |13     |
# |Cedric the Entertainer      |13     |
# |Levy, Eugene                |13     |
# |Greenwood, Bruce (I)        |13     |
# |Wahlberg, Mark (I)          |13     |
# |Faris, Anna                 |13     |
# |Chrest, Joe                 |13     |
# |Aykroyd, Dan                |13     |
# |Marshall, Mona (I)          |13     |
# |Daily, Elizabeth            |13     |
# |Bean, Sean                  |13     |
# |Trejo, Danny                |13     |
# |Bennett, Michael (VIII)     |13     |
# |Downey Jr., Robert          |13     |
# |Morshower, Glenn            |13     |
# |Pinney, Patrick             |13     |
# |Blanchett, Cate             |13     |
# |Leguizamo, John             |13     |
# |Goldberg, Whoopi            |13     |
# |Rodriguez, Gary             |13     |
# |Cheadle, Don                |13     |
# |Pepper, Bob (II)            |13     |
# |Belushi, James              |13     |
# |Gibson, Mel (I)             |13     |
# |Quaid, Dennis               |13     |
# |Loughran, Jonathan (I)      |13     |
# |Hackman, Gene               |13     |
# |Curry, Tim (I)              |13     |
# |Borgman, Eric Bruno         |13     |
# |Lynch, Jane (I)             |13     |
# |Leno, Jay                   |13     |
# |Ward, Jim (I)               |13     |
# |Ellis, Greg (II)            |13     |
# |Woodruff Jr., Tom           |13     |
# |Barrymore, Drew (I)         |13     |
# |Cooney, Kevin (I)           |13     |
# |Rhames, Ving                |13     |
# |Cusack, John                |13     |
# |Cowgill, David              |13     |
# |Meskimen, Jim               |13     |
# |Fishburne, Laurence         |13     |
# |Weisz, Steven               |13     |
# |Murray, Bill (I)            |13     |
# |Zeta-Jones, Catherine       |13     |
# |Boston, David (IV)          |12     |
# |Griffiths, Richard (I)      |12     |
# |Root, Stephen (I)           |12     |
# |Law, Jude                   |12     |
# |Fischer, Pamela (I)         |12     |
# |Davis, Warwick (I)          |12     |
# |Guest, Nicholas             |12     |
# |Levine, Ted                 |12     |
# |Allen, Tim (I)              |12     |
# |Koechner, David             |12     |
# |Glenn, Scott                |12     |
# |Richardson, Kevin Michael   |12     |
# |Hurt, William               |12     |
# |Tobolowsky, Stephen         |12     |
# |Harris, Ed (I)              |12     |
# |Marshall, Dan (II)          |12     |
# |Marsden, James (I)          |12     |
# |DeLisle, Grey               |12     |
# |Shalhoub, Tony              |12     |
# |Lawrence, Martin (I)        |12     |
# |Wilson, Michael G. (I)      |12     |
# |Di Maggio, John             |12     |
# |Miller, Larry (I)           |12     |
# |McKellen, Ian               |12     |
# |Walters, Julie (I)          |12     |
# |Lee, Jason (I)              |12     |
# |Malkovich, John             |12     |
# |Schiff, Richard             |12     |
# |Jeong, Ken                  |12     |
# |Grant, Beth                 |12     |
# |Jackman, Hugh               |12     |
# |Sheen, Michael              |12     |
# |Shannon, Molly              |12     |
# |Howard, Rance               |12     |
# |McGregor, Ewan              |12     |
# |Campbell, Bruce (I)         |12     |
# |Franco, James               |12     |
# |Reeves, Keanu               |12     |
# |Steele, Brian (I)           |12     |
# |Chan, Jackie (I)            |12     |
# |Tudyk, Alan                 |12     |
# |Anderson, Anthony (I)       |12     |
# |Harris, Rachael (I)         |12     |
# |DiCaprio, Leonardo          |12     |
# |Latifah, Queen              |12     |
# |Banks, Elizabeth (II)       |12     |
# |Vernon, Conrad              |12     |
# |Witherspoon, Reese          |12     |
# |Hunt, Bonnie                |12     |
# |Paltrow, Gwyneth            |12     |
# |LaBeouf, Shia               |12     |
# |Close, Glenn                |12     |
# |Knight, Wayne (I)           |12     |
# |Omilami, Afemo              |12     |
# |Cho, John                   |11     |
# |Cumming, Alan               |11     |
# |Dunst, Kirsten              |11     |
# |Fichtner, William           |11     |
# |Rudd, Paul (I)              |11     |
# |Jackson, Roger (VI)         |11     |
# |Crews, Terry (I)            |11     |
# |Klebba, Martin              |11     |
# |Marin, Cheech               |11     |
# |Sutherland, Donald (I)      |11     |
# |Fletcher, Anne              |11     |
# |Craig, Daniel (I)           |11     |
# |McGinley, John C.           |11     |
# |Edney, Paul                 |11     |
# |Bale, Christian             |11     |
# |Cygan, John (I)             |11     |
# |McCrary, Joel               |11     |
# |Thompson, Emma (I)          |11     |
# |Uzimann, Naeem              |11     |
# |McAdams, Rachel             |11     |
# |Caine, Michael (I)          |11     |
# |Walsh, Matt (I)             |11     |
# |Daniels, Jeff (I)           |11     |
# |Piven, Jeremy               |11     |
# |Manoux, J.P.                |11     |
# |Castellaneta, Dan           |11     |
# |Stamp, Terence              |11     |
# |Reitel, Enn                 |11     |
# |Arnett, Will                |11     |
# |Wood, Elijah                |11     |
# |Winston, Matt (I)           |11     |
# |Curtis Brown, Robert        |11     |
# |Pacino, Al                  |11     |
# |Taylor, James Arnold        |11     |
# |Alazraqui, Carlos           |11     |
# |Olsson, Ty                  |11     |
# |Cusack, Joan                |11     |
# |Durand, Kevin               |11     |
# |Schreiber, Liev             |11     |
# |Strong, Mark (II)           |11     |
# |Johnson, Dwayne (I)         |11     |
# |Jameson, Nick               |11     |
# |Lloyd, Christopher (I)      |11     |
# |von Bargen, Daniel          |11     |
# |Norton, Edward (I)          |11     |
# |Fry, Stephen (I)            |11     |
# |Felton, Tom                 |11     |
# |Eiding, Paul                |11     |
# |Dafoe, Willem               |11     |
# |Wahlgren, Kari              |11     |
# |Hahn, Archie                |11     |
# |Macaulay, Marc              |11     |
# |Johansson, Scarlett         |11     |
# |Flemyng, Jason              |11     |
# |Breslin, Abigail            |11     |
# |Monaghan, Michelle          |11     |
# |Feore, Colm                 |11     |
# |Sievers, Gary               |11     |
# |Spiner, Brent               |11     |
# |Ellis, Nadine               |11     |
# |Gough, Michael (II)         |11     |
# |Pollak, Kevin               |11     |
# |Fanning, Dakota             |11     |
# |Dick, Andy (I)              |11     |
# |Curtis, Cliff               |11     |
# |Borstein, Alex              |10     |
# |Hawkes, John (I)            |10     |
# |McClurg, Edie               |10     |
# |Jensen, David (II)          |10     |
# |Curran, Tony (I)            |10     |
# |Lopez, Jennifer (I)         |10     |
# |Oz, Frank                   |10     |
# |Berry, Halle                |10     |
# |Crowe, Russell              |10     |
# |Lyons, Derek                |10     |
# |Poehler, Amy                |10     |
# |Pyle, Missi (I)             |10     |
# |Wiles, Michael Shamus       |10     |
# |Thornton, Billy Bob         |10     |
# |Harrelson, Woody            |10     |
# |Montgomery, Ritchie         |10     |
# |Hallgrey, Johnathan         |10     |
# |Broderick, Matthew (I)      |10     |
# |Thewlis, David              |10     |
# |Sinise, Gary                |10     |
# |Garson, Willie              |10     |
# |Hedaya, Dan                 |10     |
# |Suplee, Ethan               |10     |
# |Janney, Allison             |10     |
# |Bettany, Paul               |10     |
# |Bacon, Kevin (I)            |10     |
# |Firth, Colin                |10     |
# |Taylor, Holland             |10     |
# |Pryce, Jonathan             |10     |
# |Hader, Bill                 |10     |
# |Guilfoyle, Paul (II)        |10     |
# |Serrano, Nestor (I)         |10     |
# |Margolis, Mark (I)          |10     |
# |Cheung, George              |10     |
# |Garrett, Brad (I)           |10     |
# |Dreher, Page                |10     |
# |Pinkett Smith, Jada         |10     |
# |Atkinson, Rowan             |10     |
# |Crawford, Thomas (I)        |10     |
# |Woller, Kirk B.R.           |10     |
# |Mortimer, Emily             |10     |
# |Norris, Dean (I)            |10     |
# |Russo, Rene (I)             |10     |
# |Broadbent, Jim              |10     |
# |Weston, Celia               |10     |
# |Castaldo, Craig             |10     |
# |Nicholson, Jack (I)         |10     |
# |King, Regina                |10     |
# |West, Dominic               |10     |
# |Beckinsale, Kate            |10     |
# |Lewis, Jenifer              |10     |
# |Ermey, R. Lee               |10     |
# |Kenny, Tom (I)              |10     |
# |Kain, Rick (I)              |10     |
# |Martin, Steve (I)           |10     |
# |Kanellakos, Alexander       |10     |
# |Kutcher, Ashton             |10     |
# |Jones, Doug (I)             |10     |
# |Foster, Reese               |10     |
# |Boone Junior, Mark          |10     |
# |Streep, Meryl               |10     |
# |Cohen, David (XXVIII)       |10     |
# |Lennon, Thomas (III)        |10     |
# |Bell, Tobin                 |10     |
# |Postlethwaite, Pete         |10     |
# |Shearer, Harry              |10     |
# |Williams, Mark (I)          |10     |
# |Jones, Toby (I)             |10     |
# |Lane, Diane (I)             |10     |
# |Ruffalo, Mark               |10     |
# |Diesel, Vin                 |10     |
# |Butler, Gerard              |10     |
# |Keitel, Harvey              |10     |
# |Connery, Sean               |10     |
# |Lockhart, Anne (I)          |10     |
# |Lindo, Delroy               |10     |
# |Wasilewski, Audrey          |10     |
# |Caton, Robert Randolph      |10     |
# |Elwes, Cary                 |10     |
# |Zellweger, Renée            |10     |
# |Gellar, Sarah Michelle      |10     |
# |Becker, Gerry               |10     |
# |Leung, Ken (I)              |10     |
# |Holm, Ian                   |10     |
# |Cranston, Bryan             |10     |
# |Moore, Julianne             |10     |
# |Bateman, Jason              |10     |
# |Breslin, Spencer            |10     |
# |Fogarty, Shawn              |10     |
# |Sandler, Jackie (I)         |10     |
# |Wright, Jeffrey (I)         |10     |
# |Alaskey, Joe                |10     |
# |Conboy, Peter               |10     |
# |Gregg, Clark                |10     |
# |Woods, James (I)            |10     |
# |Trainor, Mary Ellen         |10     |
# |Glover, Crispin             |10     |
# |Malloy, Matt (I)            |10     |
# |Johnson, Corey (I)          |10     |
# |Connolly, Billy (I)         |10     |
# |LeFevre, Adam               |10     |
# |Lee, Christopher (I)        |10     |
# |Molina, Alfred              |10     |
# |Menezes, João Costa         |10     |
# |Davis, Viola (I)            |10     |
# |Foxx, Jamie                 |10     |
# |Berger, Gregg               |10     |
# |Thornton, Paul (I)          |10     |
# |Lacey, Aaron Michael        |10     |
# |Zahn, Steve                 |10     |
# |Lithgow, John (I)           |10     |
# |Zajonc, Robert 'Bobby Z'    |10     |
# |Moore, Demi                 |10     |
# |Shawn, Wallace              |10     |
# |Kennedy, Jamie (I)          |10     |
# |Marsan, Eddie               |10     |
# |Bizik, Robert (I)           |10     |
# |Wahlberg, Donnie            |10     |
# |Rothman, John               |10     |
# |Nayyar, Harsh               |10     |
# |Stiers, David Ogden         |9      |
# |Lynch, John Carroll         |9      |
# |Watson, George F. (I)       |9      |
# |Walter, Tracey              |9      |
# |Kehler, Jack                |9      |
# |Muirhead, Oliver            |9      |
# |Mortensen, Viggo            |9      |
# |Weisz, Rachel               |9      |
# |Jacobson, Peter (I)         |9      |
# |Logue, Donal                |9      |
# |Avari, Erick                |9      |
# |Piddock, Jim                |9      |
# |Graf, Allan                 |9      |
# |Bloom, Orlando              |9      |
# |Knights, Christopher (I)    |9      |
# |Ciccolella, Jude            |9      |
# |Drocco, Johnny              |9      |
# |Sabongui, Patrick           |9      |
# |Rice, Brett                 |9      |
# |Coates, Kim                 |9      |
# |Willard, Fred               |9      |
# |Grevioux, Kevin             |9      |
# |Judd, Ashley                |9      |
# |Farrell, Colin (I)          |9      |
# |Russo, Gianni (I)           |9      |
# |Strange, Patrick Michael    |9      |
# |Bennett, Jimmy (III)        |9      |
# |Garrett, Spencer (I)        |9      |
# |von Sydow, Max (I)          |9      |
# |Carrington, Debbie Lee      |9      |
# |Morgan, Tracy (II)          |9      |
# |Clarkson, Patricia          |9      |
# |McNally, Kevin (I)          |9      |
# |Stream                      |9      |
# |Shatner, William            |9      |
# |Meyer, Breckin              |9      |
# |Swardson, Nick              |9      |
# |Bradley, David (IV)         |9      |
# |Eastwood, Clint             |9      |
# |Radcliffe, Daniel           |9      |
# |Nealon, Kevin               |9      |
# |Richter, Andy (I)           |9      |
# |Frierson, Eddie             |9      |
# |Sykes, Wanda                |9      |
# |Howard, Bryce Dallas        |9      |
# |Slattery, John (I)          |9      |
# |Saldana, Zoe                |9      |
# |Dye, Dale                   |9      |
# |Somerville, Geraldine       |9      |
# |Cetrone, Richard            |9      |
# |Green, Seth                 |9      |
# |Hoskins, Bob (I)            |9      |
# |Serbedzija, Rade            |9      |
# |Nixon, Richard              |9      |
# |Kilmer, Val                 |9      |
# |James, Kevin (III)          |9      |
# |Maguire, Tobey              |9      |
# |Ivanek, Zeljko              |9      |
# |Sommer, Josef               |9      |
# |Cenatiempo, John            |9      |
# |Gere, Richard               |9      |
# |Connolly, Desiree April     |9      |
# |McShane, Ian                |9      |
# |Everett, Tom                |9      |
# |Rivera, Emilio (I)          |9      |
# |Williams, Harland           |9      |
# |Torn, Rip                   |9      |
# |Nelson, Tim Blake           |9      |
# |Watson, Emma (II)           |9      |
# |Middlebrook, Keith          |9      |
# |Howe, Brian                 |9      |
# |Djalili, Omid               |9      |
# |Kassir, John                |9      |
# |Costner, Kevin              |9      |
# |Kind, Richard               |9      |
# |Schwartz, Scott L.          |9      |
# |Knightley, Keira            |9      |
# |Buescher, Julianne          |9      |
# |Doughan, Jim                |9      |
# |Milicevic, Ivana            |9      |
# |Theron, Charlize            |9      |
# |Armisen, Fred               |9      |
# |O'Hara, Catherine           |9      |
# |Crewson, Wendy              |9      |
# |Deschanel, Zooey            |9      |
# |Baker, Dylan (I)            |9      |
# |Stone, Emma (III)           |9      |
# |Doty, David                 |9      |
# |Adams, Amy (III)            |9      |
# |Bana, Eric                  |9      |
# |DuMont, James (I)           |9      |
# |Serkis, Andy                |9      |
# |Hayek, Salma                |9      |
# |Garner, Jerald              |9      |
# |Napier, Charles             |9      |
# |McCormack, J. Patrick       |9      |
# |Hathaway, Anne              |9      |
# |Caviezel, Jim               |9      |
# |Cruz, Penélope              |9      |
# |Peet, Amanda (I)            |9      |
# |Hecker, Gary A.             |9      |
# |Hagen, Thomas M.            |9      |
# |Liu, Lucy (I)               |9      |
# |Minkoff, Robert             |9      |
# |Church, Thomas Haden        |9      |
# |Campbell, Keith (I)         |9      |
# |Gleason, Mary Pat           |9      |
# |Harris, Barbara (II)        |9      |
# |Welsh, Kenneth              |9      |
# |Katt, Nicky                 |9      |
# |Robbins, Tim (I)            |9      |
# |Fallon, Siobhan             |9      |
# |Balaban, Bob                |9      |
# |Serpico, Terry              |9      |
# |Brown, Clancy (I)           |9      |
# |Dante, Peter                |9      |
# |Pressman, David (I)         |9      |
# |Kinnear, Greg               |9      |
# |Hart, Kevin (I)             |9      |
# |Hounsou, Djimon             |9      |
# |Stanton, Stephen            |9      |
# |Mapother, William           |9      |
# |Berkeley, Xander            |9      |
# |Hall, Justin Rodgers        |9      |
# |Conley, Jack                |9      |
# |West, Billy (II)            |9      |
# |Walker, Paul (I)            |9      |
# |Overton, Rick               |9      |
# |Metcalf, Laurie             |9      |
# |Baumel, Shane               |9      |
# |Doyle-Murray, Brian         |9      |
# |Winstone, Ray (I)           |9      |
# |Bennett, Jeff (I)           |9      |
# |Miller, Chris (LX)          |9      |
# |Cecere, Fulvio              |9      |
# |Llewelyn, Desmond           |9      |
# |Hutcherson, Josh            |9      |
# |Riehle, Richard             |9      |
# |Krupa, Olek                 |9      |
# |Myers, Mike (I)             |9      |
# |Travolta, Margaret          |9      |
# |Aniston, Jennifer           |8      |
# |Krumholtz, David (I)        |8      |
# |Norris, Daran               |8      |
# |Jackson, Brandon T.         |8      |
# |Barry, Thom                 |8      |
# |Greer, Judy                 |8      |
# |Shaye, Lin                  |8      |
# |Emmerich, Noah              |8      |
# |Sabara, Daryl               |8      |
# |Paquin, Anna                |8      |
# |Whyte, Joe                  |8      |
# |Forster, Robert (I)         |8      |
# |Lewis, Matthew (III)        |8      |
# |Rockwell, Sam               |8      |
# |Isyanov, Ravil              |8      |
# |Corazzini, Jeffrey          |8      |
# |Gallo, Carla (I)            |8      |
# |Madsen, Michael (I)         |8      |
# |Janssen, Famke              |8      |
# |Ahl, Michael                |8      |
# |Leary, Denis                |8      |
# |Dawson, Rosario             |8      |
# |James, Jesse (I)            |8      |
# |Sterling, Mindy             |8      |
# |Sarsgaard, Peter            |8      |
# |Sedaris, Amy                |8      |
# |Jacobi, Derek               |8      |
# |Whitley, Kym                |8      |
# |Everett, Rupert             |8      |
# |Wiest, Dianne               |8      |
# |Tomei, Marisa               |8      |
# |Yang, Jamison               |8      |
# |O'Bryan, Sean               |8      |
# |Del Gaudio, Christopher     |8      |
# |Howard, Seth                |8      |
# |Lee, Reggie (I)             |8      |
# |Sheen, Charlie (I)          |8      |
# |Jason, Peter                |8      |
# |Fraley, Pat (II)            |8      |
# |Pearce, Guy (I)             |8      |
# |Hingle, Pat                 |8      |
# |Brown, Greg (VIII)          |8      |
# |Camp, Colleen               |8      |
# |Meyer, Dina                 |8      |
# |Wright, Bonnie              |8      |
# |Johnson, Christopher Karl   |8      |
# |Herdman, Josh               |8      |
# |Mac, Bernie                 |8      |
# |Masiello, Robert            |8      |
# |Phelps, James (I)           |8      |
# |Sie, James                  |8      |
# |Mann, Leslie (I)            |8      |
# |Oglesby, Randy              |8      |
# |Foster, Jodie               |8      |
# |Short, Martin (I)           |8      |
# |Garber, Victor              |8      |
# |Galifianakis, Zach          |8      |
# |Phelps, Oliver              |8      |
# |Thomas, Leonard L.          |8      |
# |George, Brian (I)           |8      |
# |Reinhold, Judge             |8      |
# |Hawe, Mackenzie             |8      |
# |Kusatsu, Clyde              |8      |
# |Ifans, Rhys                 |8      |
# |Bergman, Mary Kay           |8      |
# |Badreya, Sayed              |8      |
# |Zager, Lynnanne             |8      |
# |Hamm, Jon (I)               |8      |
# |Muellerleile, Marianne      |8      |
# |O'Shaughnessey, Colleen     |8      |
# |Jones, Cherry (I)           |8      |
# |Jones, Orlando              |8      |
# |Kehela, Steve               |8      |
# |De Paul, Vincent            |8      |
# |Stephenson, Bob (II)        |8      |
# |Graham, Heather (I)         |8      |
# |Osborne, Holmes             |8      |
# |Jay, Tony (I)               |8      |
# |Sanchez, Lauren             |8      |
# |Philbin, Regis              |8      |
# |Segel, Jason                |8      |
# |Nolte, Nick                 |8      |
# |Griffin, Eddie (I)          |8      |
# |Stiles, Julia               |8      |
# |Cameron, Cody               |8      |
# |Futterman, Nika             |8      |
# |Sheen, Martin               |8      |
# |Gainey, M.C.                |8      |
# |Marshall, Kathleen (I)      |8      |
# |Stewart, Kristen (I)        |8      |
# |Searcy, Nick                |8      |
# |Blunt, Emily                |8      |
# |Weireter, Peter             |8      |
# |Huebel, Rob                 |8      |
# |Chubai, Dawn                |8      |
# |Shue, Elisabeth             |8      |
# |Byrne, P.J.                 |8      |
# |Csokas, Marton              |8      |
# |McGrath, Tom (IV)           |8      |
# |Remar, James                |8      |
# |Ferguson, Keith (II)        |8      |
# |Wayans, Marlon              |8      |
# |McKinnon Miller, Joel       |8      |
# |Electra, Carmen             |8      |
# |Bassett, Angela             |8      |
# |Wenham, David               |8      |
# |St. James, David            |8      |
# |Larter, Ali                 |8      |
# |Molale, Brandon             |8      |
# |Grint, Rupert               |8      |
# |Bahris, Fileena             |8      |
# |Krasinski, John             |8      |
# |Spence, Bruce (I)           |8      |
# |Winzenried, Eric            |8      |
# |Griffis, Rhoda              |8      |
# |Steenburgen, Mary           |8      |
# |Hill, Bernard (I)           |8      |
# |Rosario, José Ramón         |8      |
# |Rolston, Mark               |8      |
# |Ellis, Mark Robert          |8      |
# |Embree, James               |8      |
# |Perkins, Elizabeth (I)      |8      |
# |De Zarn, Tim                |8      |
# |Garlin, Jeff                |8      |
# |Friedlander, Judah          |8      |
# |Acovone, Jay                |8      |
# |Sutherland, Kiefer          |8      |
# |Callahan, E.J.              |8      |
# |Kubr, Mark                  |8      |
# |Sporleder, Gregory          |8      |
# |Pidgeon, Jeff               |8      |
# |Fielder, Harry              |8      |
# |Loftin, Lennie              |8      |
# |Pickett, Erin               |8      |
# |Cooper, Bradley (I)         |8      |
# |Douglas, Aaron (I)          |8      |
# |Lennox, Kai                 |8      |
# |Wittenberg, Dave (I)        |8      |
# |Presnell, Harve             |8      |
# |Riggle, Rob                 |8      |
# |Ross, Neil (I)              |8      |
# |Astin, Sean                 |8      |
# |Statham, Jason              |8      |
# |Hill, David (XXXII)         |8      |
# |Grunberg, Brad              |8      |
# |Orser, Leland               |8      |
# |Gerety, Peter               |8      |
# |Flanagan, Tommy (I)         |8      |
# |Gibson, Tyrese              |8      |
# |Dallas, Keith               |8      |
# |Chen, Terry                 |8      |
# |Anderson, Stanley           |8      |
# |Rebhorn, James              |8      |
# |Mirren, Helen               |8      |
# |Facio, Giannina             |8      |
# |Farley, John (I)            |8      |
# |Corddry, Rob                |8      |
# |Murray, Devon               |8      |
# |Liotta, Ray                 |8      |
# |Dunn, Kevin (I)             |8      |
# |Parker, Sarah Jessica       |8      |
# |Shannon, Michael (V)        |8      |
# |Ryder, Winona               |8      |
# |Elfman, Bodhi               |8      |
# |Bellucci, Monica            |8      |
# |Fanning, Elle               |8      |
# |Williamson, Mykelti         |8      |
# |Ribisi, Giovanni            |8      |
# |Pniewski, Mike              |8      |
# |Chinlund, Nick              |8      |
# |Knopf, Ren (I)              |8      |
# |Farrer, John                |8      |
# |McBride, Danny (IV)         |8      |
# |Stanton, Harry Dean         |8      |
# |Grenier, Zach               |8      |
# |Devine, Loretta             |8      |
# |Pfeiffer, Michelle          |8      |
# |Danner, Blythe              |8      |
# |Macdonald, Kelly            |8      |
# |Laresca, Vincent            |8      |
# |Platt, Oliver               |8      |
# |Schultz, Dwight             |8      |
# |Cube, Ice                   |8      |
# |Clinton, Bill (I)           |8      |
# |Henley, Barry Shabaka       |8      |
# |Joles, Bob                  |8      |
# |Hall, Regina (I)            |8      |
# |Fisher, Carrie              |8      |
# |Faison, Frankie             |8      |
# |Rajskub, Mary Lynn          |8      |
# |Swinton, Tilda              |8      |
# |Smyj, Brian                 |8      |
# |Crudup, Billy               |8      |
# |Keaton, Michael             |8      |
# |Lucas, Josh (I)             |8      |
# |Biel, Jessica               |8      |
# |Cavadini, Cathy             |8      |
# |Morris, Phil (I)            |8      |
# |Hoffman, Bridget            |8      |
# |Winslet, Kate               |8      |
# |Kretschmann, Thomas         |8      |
# |Davis, DeRay                |8      |
# |Clendenin, Curt             |8      |
# |Roy, Deep                   |8      |
# |Arthur, Michelle (I)        |8      |
# |Bucaro III, Joe             |8      |
# |Wingert, Wally              |8      |
# |Grant, Hugh (I)             |8      |
# |Stahl, Andy (I)             |8      |
# |Garner, Jennifer (I)        |7      |
# |Fullilove, Donald           |7      |
# |Freeman, Crispin            |7      |
# |Rees, Norman Campbell       |7      |
# |Underdue, Towanda           |7      |
# |Jane, Thomas                |7      |
# |Lyonne, Natasha             |7      |
# |Lillard, Matthew            |7      |
# |Arkin, Alan                 |7      |
# |McGonagle, Richard          |7      |
# |Shocknek, Kent              |7      |
# |Kingsley, Ben               |7      |
# |Eddy, Sonya                 |7      |
# |Grace, Topher               |7      |
# |Horsdal, Chelah             |7      |
# |Mears, Derek                |7      |
# |MacNeille, Tress            |7      |
# |Boen, Earl                  |7      |
# |McGowan, Tom (II)           |7      |
# |Helms, Ed (I)               |7      |
# |Baron Cohen, Sacha          |7      |
# |Wilson, Scott (I)           |7      |
# |Corrigan, Kevin (I)         |7      |
# |Kelly, Joseph Patrick       |7      |
# |Bower, Tom (I)              |7      |
# |Cerullo, Al (I)             |7      |
# |Baruchel, Jay               |7      |
# |Hill, William (I)           |7      |
# |Kydd, Jonathan              |7      |
# |Pesci, Joe                  |7      |
# |Alterman, Steve             |7      |
# |Babatundé, Obba             |7      |
# |Driver, Minnie              |7      |
# |Cyrus, Miley                |7      |
# |Ealy, Michael               |7      |
# |Baker, Kenny (I)            |7      |
# |Reeves, Phil (I)            |7      |
# |Fraser, Brendan             |7      |
# |Morton, Joe (I)             |7      |
# |LaValley, Dustin            |7      |
# |Marshall, Vanessa           |7      |
# |Lychnikoff, Pasha D.        |7      |
# |Ware, Tim (I)               |7      |
# |Ranft, Joe                  |7      |
# |Horsford, Anna Maria        |7      |
# |Taylor, Harry (I)           |7      |
# |Gale, Lorena                |7      |
# |Nimoy, Leonard              |7      |
# |Perlman, Ron                |7      |
# |MacDonald, Norm (I)         |7      |
# |Peters, Robert (I)          |7      |
# |Tull, Clyde                 |7      |
# |Nelson, Craig T.            |7      |
# |Vasut, Marek                |7      |
# |Rich, Nicholas              |7      |
# |Place, Mary Kay             |7      |
# |Andrews, Julie (I)          |7      |
# |Tian, Valerie               |7      |
# |Ludacris                    |7      |
# |Dutton, Charles S.          |7      |
# |Lister, Tommy 'Tiny'        |7      |
# |Chabert, Lacey              |7      |
# |Gugliemi, Noel              |7      |
# |Burks, Jernard              |7      |
# |Gabrielli, Elisa (I)        |7      |
# |Pollack, Sydney             |7      |
# |Whalen, Sean (I)            |7      |
# |Nichols, Lance E.           |7      |
# |Summer, Cree                |7      |
# |Fox, Michael J. (I)         |7      |
# |Ivey, Dana                  |7      |
# |Kline, Kevin                |7      |
# |Heslov, Grant               |7      |
# |Warshofsky, David           |7      |
# |Ford, Steven (I)            |7      |
# |Elliott, Chris (I)          |7      |
# |Keaton, Josh                |7      |
# |Spade, David                |7      |
# |Henriksen, Lance            |7      |
# |Sizemore, Tom               |7      |
# |Thomason, Mark (I)          |7      |
# |Bader, Diedrich             |7      |
# |Winter, Ariel               |7      |
# |Langella, Frank             |7      |
# |Bello, Maria                |7      |
# |Harvey, Robert (I)          |7      |
# |Pearl, David (III)          |7      |
# |Campbell, Ken Hudson        |7      |
# |Hale, Jennifer (I)          |7      |
# |Rankin, Steve               |7      |
# |Scott Thomas, Kristin       |7      |
# |Love, Faizon                |7      |
# |Jackson, Joshua (I)         |7      |
# |Neill, Sam                  |7      |
# |Harden, Marcia Gay          |7      |
# |Linn, Rex                   |7      |
# |Keener, Catherine           |7      |
# |White, Bernard (I)          |7      |
# |Panettiere, Hayden          |7      |
# |Monroe, Steve (I)           |7      |
# |Cramer, Rick                |7      |
# |Addy, Mark                  |7      |
# |Wilding, Spencer            |7      |
# |Hope, William               |7      |
# |Malahide, Patrick           |7      |
# |Harris, Jared (I)           |7      |
# |Roebuck, Daniel             |7      |
# |Callow, Simon               |7      |
# |Ryan, Meg                   |7      |
# |Henson, Elden               |7      |
# |Flynn, Quinton              |7      |
# |Vigman, Gillian             |7      |
# |Robinson, Craig (I)         |7      |
# |Fox, Vivica A.              |7      |
# |Kightlinger, Laura          |7      |
# |Smith, Scott Alan (I)       |7      |
# |Clotworthy, Robert          |7      |
# |Li, Jet                     |7      |
# |Wright, Robin (V)           |7      |
# |McManus, Don (I)            |7      |
# |Mendes, Eva                 |7      |
# |Jones, Richard T. (I)       |7      |
# |Tuerpe, Paul                |7      |
# |Gray, Bruce (I)             |7      |
# |Cox, Courteney              |7      |
# |Flanagan, Maile             |7      |
# |Stanton, Andrew (I)         |7      |
# |Macleod, Lewis              |7      |
# |Darga, Christopher          |7      |
# |Rawlins, Adrian             |7      |
# |Taylor, Frank Hoyt          |7      |
# |Scott, Adam (I)             |7      |
# |Arness, Andy                |7      |
# |Mason, Madison (I)          |7      |
# |Keane, James (I)            |7      |
# |Jones, January (I)          |7      |
# |Wilson, Rainn               |7      |
# |Findlater, Neil             |7      |
# |Kane, Tom (II)              |7      |
# |Evans, Chris (V)            |7      |
# |Massee, Michael             |7      |
# |Lee, Waymond                |7      |
# |Jbara, Gregory              |7      |
# |Alba, Jessica               |7      |
# |Shepherd, Sherri            |7      |
# |Tochi, Brian                |7      |
# |Grubbs, Gary                |7      |
# |Lowe, Crystal (I)           |7      |
# |Richardson, Miranda (I)     |7      |
# |Adler, Charles (I)          |7      |
# |Mackie, Anthony             |7      |
# |Hurst, Ryan (I)             |7      |
# |Ivanir, Mark                |7      |
# |Tucker, Chris (I)           |7      |
# |Gress, Googy                |7      |
# |Duffy, Thomas F.            |7      |
# |Markinson, Brian            |7      |
# |Krall, Daamen J.            |7      |
# |Gass, Kyle                  |7      |
# |Reim, Donna Glee            |7      |
# |Taylor, Russi               |7      |
# |Hoskins Mackey, Katherine   |7      |
# |Rhys-Davies, John           |7      |
# |Gulbranson, Matthew James   |7      |
# |Epps, Mike (I)              |7      |
# |Joffre, Dan                 |7      |
# |King, Jaime (I)             |7      |
# |Cole, Gary (I)              |7      |
# |Leachman, Cloris            |7      |
# |Menville, Scott             |7      |
# |Wilson, Andrew (III)        |7      |
# |Tamburro, Charles A.        |7      |
# |Heiman, Jesse               |7      |
# |Moore, Roger (I)            |7      |
# |McClure, Marc (I)           |7      |
# |Blanc, JB                   |7      |
# |Grazer, Gavin               |7      |
# |Swift, Tony                 |7      |
# |Godley, Adam                |7      |
# |Prosky, John                |7      |
# |Heche, Anne                 |7      |
# |Midler, Bette               |7      |
# |Thompson, Kenan             |7      |
# |Theobalds, Joanna           |7      |
# |Taylor, Rocky (I)           |7      |
# |Myers, Robert (IX)          |7      |
# |Tatum, Channing             |7      |
# |Benrubi, Abraham            |7      |
# |Owen, Chris (I)             |7      |
# |Fugit, Lanette              |7      |
# |Ganzel, Teresa              |7      |
# |Gauthier, Chris (I)         |7      |
# |Corduner, Allan             |7      |
# |Crystal, Billy              |7      |
# |Spielberg, Steven           |7      |
# |Reno, Jean (I)              |7      |
# |Vargas, Jacob               |7      |
# |Peña, Michael               |7      |
# |Morse, David (I)            |7      |
# |Reubens, Paul               |7      |
# |Poltoranin, Nick            |7      |
# |Wiig, Kristen               |7      |
# |Jeter, Michael              |7      |
# |Ambler, Jeremy              |7      |
# |Gruffudd, Ioan              |7      |
# |Pullman, Bill               |7      |
# |Martindale, Margo           |7      |
# |Pape, Paul                  |7      |
# |Okumoto, Yuji               |7      |
# |Jones, Jeffrey (I)          |7      |
# |Blake, Clement              |7      |
# |McCarthy, Thomas (I)        |7      |
# |McClelland, Charles (II)    |7      |
# |Gough, Michael (I)          |7      |
# |O'Connell, Jerry            |7      |
# |McConnell, John (I)         |7      |
# |Mulroney, Dermot            |7      |
# |Ameyaw, Kwesi               |7      |
# |McDormand, Frances          |7      |
# |O'Hara, David (I)           |7      |
# |Turner, Bree                |7      |
# |Becker-Gray, Ellen          |7      |
# |Elliott, Sam (I)            |7      |
# |Enoch, Alfie                |7      |
# |Coogan, Steve               |7      |
# |Gonneau, Jackie             |7      |
# |Brolin, Josh                |7      |
# |Oswalt, Patton              |7      |
# |Grady, Kevin (I)            |7      |
# |Flynn, Jackie (I)           |7      |
# |LeBlanc, Elton              |7      |
# |Judge, Mike (I)             |7      |
# |Ortiz, John (I)             |7      |
# |Howard, Rosemary (II)       |7      |
# |Currie, Brian Hayes         |7      |
# |Dwyer, David (I)            |7      |
# |Byrne, Michael (I)          |7      |
# |Mechoso, Julio Oscar        |7      |
# |Smith, Shawnee              |7      |
# |Walsh, M. Emmet             |7      |
# |Ciarfalio, Carl             |7      |
# |Walters, Melora             |7      |
# |Levy, Hope                  |7      |
# |Rodriguez, Michelle (I)     |7      |
# |Federman, Wayne             |7      |
# |Hill, Amy (I)               |7      |
# |Winn, Mark (II)             |7      |
# |Lane, Nathan (I)            |7      |
# |Oteri, Cheri                |7      |
# |Arana, Tomas                |7      |
# |Flanagan, Fionnula          |7      |
# |Brill, Steven (I)           |7      |
# |Devlin, Billy               |7      |
# |Buzzington, Ezra            |7      |
# |Howard, Jeremy (I)          |7      |
# |Ray, Connie (I)             |7      |
# |Woodard, Alfre              |7      |
# |Reiner, Tracy               |7      |
# |Spinelli, Chris (I)         |7      |
# |Taylor, Sandra (I)          |7      |
# |Ma, Raymond                 |7      |
# |Walsh, Kate (I)             |7      |
# |Affleck, Casey              |7      |
# |Warren, Steve (III)         |7      |
# |Morrison, Temuera           |7      |
# |Garlington, Lee             |7      |
# |Olyphant, Timothy           |7      |
# |Dorn, Michael (I)           |7      |
# |Bishop, Stephen (II)        |7      |
# |Bacarella, Mike             |7      |
# |Bridges, Jeff (I)           |7      |
# |Kraish, Mousa               |7      |
# |Schofield, David (I)        |7      |
# |Murphy, Cillian             |7      |
# |Sussman, Kevin              |7      |
# |Baskin, Elya                |7      |
# |Cattrall, Kim               |7      |
# |Collette, Toni              |7      |
# |Riviezzo, Vincent           |7      |
# |Richmond, Branscombe        |7      |
# |Baker, Joe Don              |7      |
# |Eckhart, Aaron              |7      |
# |Sarandon, Susan             |7      |
# |Turturro, Nicholas          |7      |
# |Volok, Ilia                 |7      |
# |Palermo, Chris (III)        |7      |
# |Young, Keone                |7      |
# |Kirkwood, Jordan            |7      |
# |Lustig, Aaron               |7      |
# |McCallany, Holt             |6      |
# |Howard, Ken (I)             |6      |
# |Diehl, John                 |6      |
# |Scott, Kimberly (I)         |6      |
# |Gould, Geoffrey             |6      |
# |Mueller-Stahl, Armin        |6      |
# |Hocke, Bernard              |6      |
# |Skipper, Pat                |6      |
# |Newton, Teddy               |6      |
# |Lawrence, Mark Christopher  |6      |
# |Leoni, Téa                  |6      |
# |Andris, Martin              |6      |
# |Pesce, Frank                |6      |
# |Kim, Randall Duk            |6      |
# |Lindberg, Chad              |6      |
# |Dorff, Holly                |6      |
# |Martin, Andrea (I)          |6      |
# |Parson, Chris (I)           |6      |
# |Cross, Roger R.             |6      |
# |Foley, Dave (I)             |6      |
# |Cothran Jr., John           |6      |
# |Ferguson, Liam              |6      |
# |Regan, Vincent              |6      |
# |Cressida, Kathryn           |6      |
# |Cruz, Raymond (I)           |6      |
# |Heigl, Katherine            |6      |
# |Keener, Brandon (I)         |6      |
# |Elizondo, Hector (I)        |6      |
# |Watanabe, Ken (I)           |6      |
# |Garcia, Jeffrey (I)         |6      |
# |Weston II, James D.         |6      |
# |Alexi-Malle, Adam           |6      |
# |Lovitz, Jon                 |6      |
# |Scott, Esther (II)          |6      |
# |Dell, Charlie (I)           |6      |
# |Linney, Laura               |6      |
# |Clarke, Cam                 |6      |
# |Gilbert, Taylor (II)        |6      |
# |Moynahan, Bridget           |6      |
# |Moretz, Chloë Grace         |6      |
# |Rennie, Callum Keith        |6      |
# |Grossman, Ted (I)           |6      |
# |Stoner, Alyson              |6      |
# |Pattinson, Robert (I)       |6      |
# |Pepper, Barry               |6      |
# |Corbett, John (I)           |6      |
# |Waters, Dina                |6      |
# |Douglas, Terri              |6      |
# |Shen, Freda Foh             |6      |
# |Atkins, Lasco               |6      |
# |Connolly, Kevin (I)         |6      |
# |Urban, Karl                 |6      |
# |Ferrer, Miguel (I)          |6      |
# |Yeoh, Michelle              |6      |
# |Miller, Mark Jeffrey        |6      |
# |Lucking, William            |6      |
# |Malco, Romany               |6      |
# |Factora, Marshall           |6      |
# |Ubach, Alanna               |6      |
# |Kelly, Brendan (I)          |6      |
# |Goossen, Greg               |6      |
# |Waylett, Jamie              |6      |
# |Ironside, Michael           |6      |
# |Jenney, Lucinda             |6      |
# |Rosario, Marcio             |6      |
# |Palmer, Jim (I)             |6      |
# |McKinnon, Ray               |6      |
# |Smart, Jean                 |6      |
# |Byrne, Rose                 |6      |
# |Common                      |6      |
# |Malone, Jena                |6      |
# |Ahn, Rio                    |6      |
# |Rouillier, Ross             |6      |
# |Paul, Jarrad                |6      |
# |Mazar, Debi                 |6      |
# |Arquette, David             |6      |
# |Hoffman, Rick (I)           |6      |
# |O'Brien, Patrick Thomas     |6      |
# |Henson, Taraji P.           |6      |
# |Goritsas, Demetri           |6      |
# |Haley, Brian                |6      |
# |Boyle, Peter (I)            |6      |
# |Ruginis, Vyto               |6      |
# |Cartwright, Nancy (I)       |6      |
# |Smart, Amy                  |6      |
# |Turner, Kathleen (I)        |6      |
# |Applegate, Royce D.         |6      |
# |Herlihy, Tim                |6      |
# |Mueting, Alan               |6      |
# |Wainwright III, Loudon      |6      |
# |Genaro, Tony                |6      |
# |Frost, Roger (I)            |6      |
# |Brown, Billy (II)           |6      |
# |Thurman, Uma                |6      |
# |Curtis, Jamie Lee           |6      |
# |Vergara, Sofía              |6      |
# |Rodriguez, Valente          |6      |
# |Iwanonkiw, John W.          |6      |
# |Troyer, Verne               |6      |
# |Gordon-Levitt, Joseph       |6      |
# |Loren, Nick                 |6      |
# |Ganis, Sidney               |6      |
# |Long, Nia                   |6      |
# |Concha, Billy               |6      |
# |Rosales, Gilbert            |6      |
# |McDowell, Malcolm           |6      |
# |Metas, Christopher          |6      |
# |Lansbury, Angela            |6      |
# |Paymer, David               |6      |
# |McRobbie, Peter             |6      |
# |Lotterman, Beau             |6      |
# |Blakeslee, Susanne          |6      |
# |Milhoan, Michael            |6      |
# |Owen, Clive (I)             |6      |
# |McCharen, David             |6      |
# |Christian, Troy             |6      |
# |Sagastizado I, Tony         |6      |
# |Kelly, Michael (V)          |6      |
# |Ducommun, Rick              |6      |
# |Takei, George               |6      |
# |Chapman, Kevin (I)          |6      |
# |Ensign, Michael             |6      |
# |Todd, Tony (I)              |6      |
# |Chan, Michael Paul          |6      |
# |Giles, Ronald E.            |6      |
# |LaMarche, Maurice           |6      |
# |Macfadyen, Angus (I)        |6      |
# |Huston, Danny               |6      |
# |Lapira, Liza                |6      |
# |Nappo, Tony                 |6      |
# |Christopher, June           |6      |
# |Hall, Irma P.               |6      |
# |Jefferies, Marc John        |6      |
# |Blake, Geoffrey             |6      |
# |Manson, Ted                 |6      |
# |Mumy, Liliana               |6      |
# |Davis, Kristin (I)          |6      |
# |Hanner, Zach                |6      |
# |Hosking, Craig              |6      |
# |Walsh, Wendy L.             |6      |
# |Gaston, Michael (I)         |6      |
# |Hughes, Miko (I)            |6      |
# |Rourke, Mickey              |6      |
# |Friend, Ted                 |6      |
# |Vigus, Larry                |6      |
# |Champeau, Isabelle          |6      |
# |Gyllenhaal, Jake            |6      |
# ...
# |Nolan, Paul L.              |3      |
# |Fiore, Aaron                |3      |
# |Ali, Tatyana                |3      |
# |Rosado, Luis (II)           |3      |
# |Flynn, Colleen (I)          |3      |
# |Parks Jordan, Jonathan      |3      |
# |Borras, John                |3      |
# |Yune, Karl                  |3      |
# |Capp, Christopher S.        |3      |
# |Jennings, Alex (I)          |3      |
# |Sidora, Drew                |3      |
# |Michaels, Rick (I)          |3      |
# |Darmane, Doshia             |3      |
# |Riojas, Juan A.             |3      |
# |Close, Joshua               |3      |
# |Fernandez, Alex (I)         |3      |
# |Edwards, Paddi              |3      |
# |Cottle, Jason               |3      |
# |Xzibit                      |3      |
# |Cavill, Henry               |3      |
# |Barnett, Craig (I)          |3      |
# |Kinsey, Lance               |3      |
# |Watson, Muse                |3      |
# |Herbert, Daren A.           |3      |
# |Leigh, Coco                 |3      |
# |Purvis, Jon                 |3      |
# |Guest, Christopher (I)      |3      |
# |Morrow, Andy                |3      |
# |Amendola, Tony (I)          |3      |
# |Pfennigwerth, Jared         |3      |
# |Basile, Joseph              |3      |
# |Pergament, Annika           |3      |
# |Stern, Daniel (I)           |3      |
# |Ciardi, Mark                |3      |
# |Hicks, Mark (I)             |3      |
# |Van Graas, Daniella         |3      |
# |Knight, Shirley (I)         |3      |
# |Correy, Mark                |3      |
# |Wallis, Annabelle           |3      |
# |Martz, Jamie                |3      |
# |Watkins, Jason (I)          |3      |
# |Graham, Kat                 |3      |
# |Trebek, Alex                |3      |
# |Ramm, Haley                 |3      |
# |Prosky, Robert              |3      |
# |Hartung, Petra              |3      |
# |Sandler, Ethan              |3      |
# |Hollis, Tommy (I)           |3      |
# |Woodington, Albie           |3      |
# |West, Kevin (I)             |3      |
# |Aguilar, G.A.               |3      |
# |Cusack, Dick                |3      |
# |Timmis, Conor               |3      |
# |King, Christopher (VIII)    |3      |
# |Meredith, Burgess           |3      |
# |Hornsby, Russell (I)        |3      |
# |Britton, Chris (II)         |3      |
# |Barry, Nina                 |3      |
# |Hill, Dulé                  |3      |
# |Bullock, Gary               |3      |
# |Jones, Kelly (VII)          |3      |
# |Stallone, Frank (I)         |3      |
# |Koenig, Walter (I)          |3      |
# |McClain, John (III)         |3      |
# |Talman, Ann                 |3      |
# |Sweeney, Ryan (I)           |3      |
# |Howard, Jean Speegle        |3      |
# |Kim, Daniel Dae             |3      |
# |Graves, Richard (V)         |3      |
# |Jaime San Andres            |3      |
# |Jiménez, Héctor (I)         |3      |
# |O'Rourke, Richard (I)       |3      |
# |Lewandowski, Bob            |3      |
# |Jimz, Edgar                 |3      |
# |Maryott, Kirsten            |3      |
# |Chon, Justin                |3      |
# |Cohn, Ethan (I)             |3      |
# |Cross, Ben (I)              |3      |
# |Liufau, Sidney S.           |3      |
# |Symonds, Robert             |3      |
# |Dona, Eliana                |3      |
# |Palmer, Keke                |3      |
# |Francis, Alan (III)         |3      |
# |Skorstad, Ben               |3      |
# |Kemper, Ellie               |3      |
# |Hammer, Armie               |3      |
# |Guinness, Peter (I)         |3      |
# |Mackenzie, Peter (I)        |3      |
# |Bouchner, Vitezslav         |3      |
# |Gates, Alan (II)            |3      |
# |Beasley, Allyce             |3      |
# |Cook, Candice               |3      |
# |Spiegel, Scott              |3      |
# |Pulido, Alex                |3      |
# |Woodbury, Judith            |3      |
# |Lafferty, Sandra Ellis      |3      |
# |Wohl, David (I)             |3      |
# |Richards, Sal               |3      |
# |Lake, Sean R.               |3      |
# |Shapi, Hassani              |3      |
# |Conti, Alexander            |3      |
# |Ross, Ricco                 |3      |
# |Morgan, Scott Michael       |3      |
# |Qin, Shaobo                 |3      |
# |Brown, Sho                  |3      |
# |Smith, Tasha (I)            |3      |
# |Remsen, Bert                |3      |
# |Tay, Sharon                 |3      |
# |Canals-Barrera, Maria       |3      |
# |Michaels, Julie (I)         |3      |
# |Thomas, Chris D.            |3      |
# |Frye, Don                   |3      |
# |Pankow, Joanne              |3      |
# |Bostick, Devon              |3      |
# |Graham, Campbell            |3      |
# |Michaels, Norma             |3      |
# |Makoare, Lawrence           |3      |
# |O'Connell, Deirdre (I)      |3      |
# |Gutiérrez, Thelma           |3      |
# |Sanchez, Phillip (I)        |3      |
# |Marshall, Lori (I)          |3      |
# |Hernández, Maximiliano      |3      |
# |Littlefield, John (I)       |3      |
# |Corey, Dave (I)             |3      |
# |Gong, Li                    |3      |
# |McGuire, Darren             |3      |
# |Ressy, Dawn                 |3      |
# |Schoeppner, Shane           |3      |
# |Garrick, David (II)         |3      |
# |Paroo, Zahf                 |3      |
# |Denkin, Marty               |3      |
# |Darling, Russell            |3      |
# |Levine, Floyd               |3      |
# |Brandon, Mark (I)           |3      |
# |Franklin, Vincent           |3      |
# |Shum Jr., Harry             |3      |
# |Itzin, Gregory              |3      |
# |Millar, Brigitte            |3      |
# |Gibb, Donald                |3      |
# |Osorio, Rafael (I)          |3      |
# |Gordon, Kiowa               |3      |
# |Guiry, Tom                  |3      |
# |Stashwick, Todd             |3      |
# |Camacho, Mark               |3      |
# |Rooney, Mickey (I)          |3      |
# |Watson, Kevin (I)           |3      |
# |Christopher, Dyllan         |3      |
# |Costanzo, Robert            |3      |
# |Carson, Terrence 'T.C.'     |3      |
# |Northam, Jeremy             |3      |
# |Wright, Marty (I)           |3      |
# |Johnson, Mike (VI)          |3      |
# |Gard, Cassidy               |3      |
# |Beach, Cameron              |3      |
# |Struff, David               |3      |
# |Heard, Amber                |3      |
# |Doyle, Shawn (I)            |3      |
# |Dean, Allison (I)           |3      |
# |O, Henry                    |3      |
# |Luyben, Kate                |3      |
# |Sobolov, David              |3      |
# |Martinez, Olivier (I)       |3      |
# |May, Seth Michael           |3      |
# |Murphy, Michael (I)         |3      |
# |Oliver, Jay (I)             |3      |
# |Paterson, Bill (I)          |3      |
# |Renaday, Peter              |3      |
# |James, Hawthorne            |3      |
# |Ottavino, John (I)          |3      |
# |Maguire, George (I)         |3      |
# |Keyes, Irwin                |3      |
# |Cash, Dylan                 |3      |
# |Alexsen, Andre              |3      |
# |Metrano, Art                |3      |
# |Sciacca, Nicole             |3      |
# |Lanza, Angela               |3      |
# |Brainard, Cam               |3      |
# |Kogan, Milt                 |3      |
# |Fischman, Ruben             |3      |
# |Emerick, Gerald             |3      |
# |Butler, Basilina            |3      |
# |Ferreri, Mark J.            |3      |
# |Brown, Garrett M.           |3      |
# |Ayala, Andrew               |3      |
# |Heavy D                     |3      |
# |Halla                       |3      |
# |Genet, Michael (I)          |3      |
# |Forest, Denis               |3      |
# |Richardson, LaTanya         |3      |
# |Hennessy, Jill              |3      |
# |Wallace, George (I)         |3      |
# |Corrigan, Peter (II)        |3      |
# |Cummins, Gregory Scott      |3      |
# |Brown, Troy (I)             |3      |
# |Hodge, Edwin                |3      |
# |Hudgens, Vanessa            |3      |
# |Gramm, Phillip              |3      |
# |Araskog, Julie              |3      |
# |Kristol, Grant Blanks       |3      |
# |Beene, Dan                  |3      |
# |Granville, James            |3      |
# |Martin, Duane               |3      |
# |West, Red                   |3      |
# |Leonardo, Chantelle         |3      |
# |Gallagher, Peter (I)        |3      |
# |Irwin, Bill (I)             |3      |
# |Coster, Ritchie             |3      |
# |Hollis, Ted (I)             |3      |
# |Braine, Richard             |3      |
# |Asai, Woodrow W.            |3      |
# |Perrine, Valerie            |3      |
# |Matthews, Al                |3      |
# |Simmons, J. Nathan          |3      |
# |Zurer, Ayelet               |3      |
# |Roberts, Bruce (IV)         |3      |
# |Rodriguez, Ramon (II)       |3      |
# |Challita, Eddy              |3      |
# |Polcyn, Beverly             |3      |
# |Leong, Al                   |3      |
# |Granville, Hollis           |3      |
# |Gale, Ed                    |3      |
# |Settle, Matthew (I)         |3      |
# |Mitchell, E. Roger          |3      |
# |Chao, Vic                   |3      |
# |Tsou, Yee                   |3      |
# |Levinson, Tamara            |3      |
# |Parrott, Tomasina           |3      |
# |Goodman-Hill, Tom           |3      |
# |Ortiz, Laura (I)            |3      |
# |Miller, Lori (V)            |3      |
# |Hult, Chloé                 |3      |
# |Burkholder, Max             |3      |
# |Jackson, Reginald (VI)      |3      |
# |Bower, Michael (I)          |3      |
# |Genovese, Anthony           |3      |
# |Leonidas, Georgina (I)      |3      |
# |Dennis, Alfred              |3      |
# |Romano, Lou                 |3      |
# |Bugeja, Gail                |3      |
# |Stadulis, Christopher       |3      |
# |Lenox, Adriane              |3      |
# |Baquerot, Aliane            |3      |
# |Jones, John Christopher     |3      |
# |Lewis, Gary (III)           |3      |
# |O'Donnell, Steven (I)       |3      |
# |Sparks, Hal                 |3      |
# |Stedman, Anne               |3      |
# |Ho, Steven (I)              |3      |
# |Blanco, Lydia               |3      |
# |Riegert, Peter              |3      |
# |Corman, Maddie              |3      |
# |Winchell, April             |3      |
# |Robison, Emily              |3      |
# |Roth, Brenna                |3      |
# |Vooren, Gerrit (I)          |3      |
# |Proops, Greg                |3      |
# |Dorman, Kevin               |3      |
# |Rogers, Cort                |3      |
# |Hunter, Holly               |3      |
# |Deutsch, Patti              |3      |
# |Salgado, Luis (III)         |3      |
# |Dauplaise, Jareb            |3      |
# |McDavid, Laura              |3      |
# |Ritter, Huntley             |3      |
# |Emery, Gideon               |3      |
# |Vaughn-Hulbert, Mashiah     |3      |
# |Wolf, Warner                |3      |
# |Albrizzi, Tucker            |3      |
# |Bjelac, Predrag             |3      |
# |Mottram, Mark               |3      |
# |Ochoa, Raymond              |3      |
# |Fair, Mel                   |3      |
# |Nazimek, Larry              |3      |
# |Metcalf, Mycole             |3      |
# |O'Donohue, Ryan             |3      |
# |Owens, John (I)             |3      |
# |Stewart, Lori (I)           |3      |
# |Schwaar, Laurent            |3      |
# |Kennedy, Robert F.          |3      |
# |Taylor, Matthew W.          |3      |
# |Patton, Jim (III)           |3      |
# |Donahue, Elinor             |3      |
# |Unger, Billy                |3      |
# |Reynolds, Debbie (I)        |3      |
# |Benítez, Benjamín (I)       |3      |
# |Billings, Earl              |3      |
# |Stowe, Madeleine            |3      |
# |Coleman, Jim R. (I)         |3      |
# |Kelly, Mary A.              |3      |
# |Chase, Cheryl (I)           |3      |
# |Powell, Clifton             |3      |
# |Lewis, Algerita Wynn        |3      |
# |Kulhavy, Milos              |3      |
# |Wiggins, Roger              |3      |
# |Scales, Crystal             |3      |
# |Kain, Shauna                |3      |
# |Rivers, Joan                |3      |
# |Wever, Merritt              |3      |
# |Hohn, Amy                   |3      |
# |Ne-Yo                       |3      |
# |Newman, Barry (I)           |3      |
# |Adlon, Pamela               |3      |
# |Robinson, Harry (III)       |3      |
# |Taylor, Erica (I)           |3      |
# |Maines, Steven              |3      |
# |Miller, George F.           |3      |
# |Lees, Nathaniel (I)         |3      |
# |Baker, Kathy (I)            |3      |
# |Neely, Cam                  |3      |
# |Ruge, George Marshall       |3      |
# |Bolton, Buddy               |3      |
# |Saunders, Kendall           |3      |
# |Saïd, Sam Georges           |3      |
# |Barriere, Jessica Marie     |3      |
# |Wright, Nathan (I)          |3      |
# |Leonard, Joshua             |3      |
# |Hughes, Kenneth (I)         |3      |
# |Berkel, Christian           |3      |
# |Williams, Billy 'Sly'       |3      |
# |Tisdale, Ashley             |3      |
# |Nakamura, Saemi             |3      |
# |Chalupa, Václav             |3      |
# |Thompson, Al (II)           |3      |
# |Jennings, Juanita           |3      |
# |Burkley, Eva                |3      |
# |Herthum, Harold G.          |3      |
# |Kelly, James Martin         |3      |
# |DiAlencar, Elisangela       |3      |
# |Parrott, Billy              |3      |
# |Pungitore, John             |3      |
# |Schaff, Andrew              |3      |
# |Lam, Larry                  |3      |
# |Yassukovich, Tatyana        |3      |
# |Hammond, Roger              |3      |
# |Meyer, Ralph H.             |3      |
# |Green, Tom (III)            |3      |
# |Lloyd-Pack, Roger           |3      |
# |Pratt, Chris (I)            |3      |
# |Moore, John (VIII)          |3      |
# |Palmer, Geoffrey (I)        |3      |
# |Voigt, Carsten              |3      |
# |Veizaga, Juan Pablo         |3      |
# |Novello, Don                |3      |
# |Maestro, Mía                |3      |
# |Parsons, Benny              |3      |
# |Wright, Marcia (I)          |3      |
# |Frazer, Rupert              |3      |
# |Adler, Lauren               |3      |
# |Frazen, Diane               |3      |
# |Thomas, Charlie (II)        |3      |
# |Cordeiro, Rick              |3      |
# |Williams, Victor (I)        |3      |
# |Berman, Shelley             |3      |
# |Blethyn, Brenda             |3      |
# |Lucero, Mason               |3      |
# |Farmer, Lonnie              |3      |
# |Nielsen, John (I)           |3      |
# |Reevis, Steve               |3      |
# |MacKenzie, J.C.             |3      |
# |Bassett, Linda (I)          |3      |
# |Morayta, Paco               |3      |
# |Callan, Justin              |3      |
# |Houseman, Tyson             |3      |
# |Grant, David Marshall       |3      |
# |Falcone, Ben (I)            |3      |
# |Henry, Guy (I)              |3      |
# |Eisenmann, Ike              |3      |
# |Dean, Robertson             |3      |
# |Butler Harner, Jason        |3      |
# |Nesting, David M.           |3      |
# |Osborne, Kevin (I)          |3      |
# |Zien, Chip                  |3      |
# |Leake, Damien               |3      |
# |Bakaitis, Helmut            |3      |
# |Oliver, Mark (I)            |3      |
# |Morgan, Jeffrey Dean        |3      |
# |O'Donnell, Keir             |3      |
# |Weiss, Gelsey               |3      |
# |Arterton, Gemma             |3      |
# |Thomas, Jake (I)            |3      |
# |DeVeaux, Nathaniel          |3      |
# |Edner, Bobby                |3      |
# |Fehmel, Sommer              |3      |
# |Wiebe, Cainan               |3      |
# |Marshall, Paul (X)          |3      |
# |Perez, Jonathan 'Legacy'    |3      |
# |Patel, Dev (I)              |3      |
# |Kelly, George (II)          |3      |
# |Leigh, Katie                |3      |
# |Bender, Lawrence            |3      |
# |Chadov, Aleksey             |3      |
# |Steele, Nick (I)            |3      |
# |Apgar, Jen                  |3      |
# |Leder, Erwin                |3      |
# |Ruscoe, Alan                |3      |
# |Werntz, Hannah              |3      |
# |Gabrielyan, Sergey          |3      |
# |Edling, Ken                 |3      |
# |Henry, Michael Tyler        |3      |
# |Davis, Vicki                |3      |
# |Klaszky, Steven J.          |3      |
# |Savaria, Ellen              |3      |
# |Benzon, Jarl                |3      |
# |Gayheart, Rebecca           |3      |
# |Yee, Nancy (I)              |3      |
# |Nelson, Danny (I)           |3      |
# |Durso, Sue                  |3      |
# |Gibson, Russell (II)        |3      |
# |Copeland, Tara (I)          |3      |
# +----------------------------+-------+

# %%
# 2. Calcule la cantidad de películas producidas cada año. La salida debe tener tres columnas: año, siglo al que pertenece el año y conteo. La salida debe ordenarse por el conteo en orden descendente.

@udf(returnType=IntegerType())
def century(year: int) -> int:
    return year // 100 + 1

films_by_year = (
    movies_df
    .groupBy("año")
    .agg(
        countDistinct("pelicula").alias("total_films")
    )
    .withColumn(
        "century",
        century(col("año")),
    )
    .orderBy(
        desc("total_films"),
    )
)

films_by_year.show(
    n=films_by_year.count(),
    truncate=False,
)
# Out:
# +----+-----------+-------+
# |año |total_films|century|
# +----+-----------+-------+
# |2011|86         |21     |
# |2004|86         |21     |
# |2006|86         |21     |
# |2005|85         |21     |
# |2008|82         |21     |
# |2002|81         |21     |
# |2010|78         |21     |
# |2000|77         |21     |
# |2003|76         |21     |
# |2007|75         |21     |
# |2001|71         |21     |
# |2009|68         |21     |
# |1999|67         |20     |
# |1997|66         |20     |
# |1998|59         |20     |
# |1996|42         |20     |
# |2012|32         |21     |
# |1995|25         |20     |
# |1994|16         |20     |
# |1986|16         |20     |
# |1992|14         |20     |
# |1984|13         |20     |
# |1993|13         |20     |
# |1990|11         |20     |
# |1985|11         |20     |
# |1987|9          |20     |
# |1988|9          |20     |
# |1982|9          |20     |
# |1989|8          |20     |
# |1983|8          |20     |
# |1991|8          |20     |
# |1981|6          |20     |
# |1979|5          |20     |
# |1977|3          |20     |
# |1978|3          |20     |
# |1980|3          |20     |
# |1975|1          |20     |
# |1961|1          |20     |
# |1973|1          |20     |
# |1967|1          |20     |
# |1972|1          |20     |
# +----+-----------+-------+

# %%
# 3. Obtenga la película con la calificación más alta por año. La salida debe tener solo una película por año y debe contener tres columnas: año, título de la película y valoración.

window_spec = Window().partitionBy(movie_ratings_df.año).orderBy(desc(movie_ratings_df.valoracion))

foty = (
    movie_ratings_df
    .withColumn(
        "rank",
        rank().over(window_spec)
    )
    .filter(
        col("rank") == 1,
    )
    .select(
        "año",
        "pelicula",
        "valoracion",
        "rank",
    )
    .orderBy(
        col("año").desc(),
    )
)

foty.show(
    n=foty.count(),
    truncate=False,
)
# Out:
# +----+-------------------------------+----------+----+
# |año |pelicula                       |valoracion|rank|
# +----+-------------------------------+----------+----+
# |2013|The Wolverine                  |12.5      |1   |
# |2012|1066                           |12.8205   |1   |
# |2011|Ang babae sa septic tank       |14.1527   |1   |
# |2010|Beginners                      |14.2173   |1   |
# |2009|Kimmy Dora: Kambal sa kiyeme   |13.7234   |1   |
# |2008|Man on Wire                    |14.0356   |1   |
# |2007|Hostel: Part II                |13.7432   |1   |
# |2006|Love and Other Disasters       |13.7696   |1   |
# |2005|The Man                        |14.1976   |1   |
# |2004|Sleepover                      |14.2073   |1   |
# |2003|Gigli                          |14.1829   |1   |
# |2002|Extreme Ops                    |12.8821   |1   |
# |2001|Tortilla Soup                  |14.0009   |1   |
# |2000|Taxi 2                         |14.1178   |1   |
# |1999|Sofies verden                  |14.0421   |1   |
# |1998|My Giant                       |14.015    |1   |
# |1997|Leave It to Beaver             |13.7106   |1   |
# |1996|Sgt. Bilko                     |14.1      |1   |
# |1995|Something to Talk About        |13.0879   |1   |
# |1994|Änglagård - Andra sommaren     |14.1242   |1   |
# |1993|What's Love Got to Do with It  |13.8594   |1   |
# |1992|Stop! Or My Mom Will Shoot     |14.1621   |1   |
# |1991|New Jack City                  |12.8001   |1   |
# |1990|Young Guns II                  |13.6317   |1   |
# |1989|Three Fugitives                |12.7532   |1   |
# |1988|Colors                         |13.9049   |1   |
# |1987|Planes, Trains & Automobiles   |14.0193   |1   |
# |1986|An American Tail               |14.2122   |1   |
# |1985|One Magic Christmas            |14.0082   |1   |
# |1984|Dune                           |13.6413   |1   |
# |1983|The Golden Seal                |13.9389   |1   |
# |1982|Making Love                    |13.9327   |1   |
# |1981|La guerre du feu               |12.5156   |1   |
# |1980|Raging Bull                    |13.4091   |1   |
# |1979|Dracula                        |13.5028   |1   |
# |1978|The End                        |11.5913   |1   |
# |1977|Oh, God!                       |13.2929   |1   |
# |1976|The Enforcer                   |13.724    |1   |
# |1975|Monty Python and the Holy Grail|8.6584    |1   |
# |1974|The Godfather: Part II         |8.793     |1   |
# |1973|The Way We Were                |13.6963   |1   |
# |1972|Deliverance                    |13.8569   |1   |
# |1971|A Clockwork Orange             |13.1181   |1   |
# |1970|The AristoCats                 |13.2917   |1   |
# |1969|Bitka na Neretvi               |14.0815   |1   |
# |1968|The Love Bug                   |13.4383   |1   |
# |1967|The Dirty Dozen                |13.388    |1   |
# |1966|Who's Afraid of Virginia Woolf?|11.1111   |1   |
# |1965|Doctor Zhivago                 |4.9304    |1   |
# |1964|My Fair Lady                   |7.587     |1   |
# |1963|It's a Mad Mad Mad Mad World   |6.626     |1   |
# |1962|The Longest Day                |12.8866   |1   |
# |1961|One Hundred and One Dalmatians |0.6726    |1   |
# |1960|Psycho                         |10.6375   |1   |
# |1959|Sleeping Beauty                |6.3919    |1   |
# |1956|Around the World in Eighty Days|14.0607   |1   |
# |1955|Lady and the Tramp             |5.1258    |1   |
# |1954|Rear Window                    |10.7625   |1   |
# |1953|Peter Pan                      |5.4756    |1   |
# |1950|Cinderella                     |9.4226    |1   |
# |1946|Song of the South              |7.602     |1   |
# |1942|Bambi                          |1.5053    |1   |
# |1940|Pinocchio                      |7.8557    |1   |
# |1939|The Wizard of Oz               |7.9215    |1   |
# |1937|Snow White and the Seven Dwarfs|2.2207    |1   |
# +----+-------------------------------+----------+----+
